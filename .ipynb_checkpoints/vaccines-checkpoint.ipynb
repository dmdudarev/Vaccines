# %% [markdown]
# Обработка данных

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
DATASET_PATH = '2021_3.csv'

# %%
df = pd.read_csv(DATASET_PATH, sep='|')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6675 entries, 0 to 6674
# Columns: 146 entries, Дата публикации тендера to ProductIdNx
# dtypes: float64(22), object(124)
# memory usage: 7.4+ MB

# %%
df.head()
# Out:
#   Дата публикации тендера Дата создания тендера Дата обновления тендера  \
# 0        44561,7368055556      44565,0013888889               44575,375
# 1        44561,7368055556      44565,0013888889               44575,375
# 2        44560,6548611111             44560,675        44604,0944444444
# 3        44560,6548611111             44560,675        44604,0944444444
# 4        44560,5333333333      44560,5569444444        44596,3604166667
#
#                  Заказ № Этап размещения заказа  \
# 0  № 0321300051321000108   размещение завершено
# 1  № 0321300051321000108   размещение завершено
# 2          № 32111014144   размещение завершено
# 3          № 32111014144   размещение завершено
# 4  № 0873400003921000463   размещение завершено
#
#                  Способ размещения заказа     Категория закупки  \
# 0    открытый аукцион в электронной форме  Госпитальные закупки
# 1    открытый аукцион в электронной форме  Госпитальные закупки
# ...

# %%
df.describe()
# Out:
#        Количество Лотов  Количество опубликованных контрактов  \
# count       6674.000000                           6674.000000
# mean           1.485766                              1.653281
# std            4.314879                              4.328482
# min            1.000000                              0.000000
# 25%            1.000000                              1.000000
# 50%            1.000000                              1.000000
# 75%            1.000000                              1.000000
# max           72.000000                             50.000000
#
#        Причина отмены тендера  Комментарий   Номер лота  \
# count                     0.0          0.0  6674.000000
# mean                      NaN          NaN     1.379533
# std                       NaN          NaN     3.532590
# min                       NaN          NaN     1.000000
# 25%                       NaN          NaN     1.000000
# 50%                       NaN          NaN     1.000000
# ...
